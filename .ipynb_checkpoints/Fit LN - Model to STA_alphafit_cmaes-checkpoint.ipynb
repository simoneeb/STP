# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
import pickle
import pandas as pd
import pyret
from scipy.ndimage import gaussian_filter
from scipy.ndimage import convolve1d
from scipy.optimize import curve_fit
from numpy import unravel_index
import scipy
import os
import cma

# %%
# compute error
def compute_mse(y,prediction):
    
    T = len(y)
    error = 0
    for i,yi in enumerate(y): 
        error += (prediction[i]-yi)**2
    error /= T
    error = np.sqrt(error)
    return error





def optimize_evol(func,x0,nb_repeats = 200, popsize = 20, sigma0 = 0.03):
    x0 = np.log(x0)
    es = cma.CMAEvolutionStrategy(x0, sigma0, {'popsize' : popsize})

    for n in range(nb_repeats):
        
        paramsets = es.ask()
        errors = []
        for set in paramsets:
            pred = func(filtertime,np.exp(set))
            err = compute_mse(time_rf_smooth,pred)
            errors.append(err)

        es.tell(paramsets,errors)
        es.disp()

    return es

# %% [markdown]
# # Fit Linear fiter of the model, biphasic as difference of alpha profiles

# %%
# model to predict, 4 params
def linear_filter_model(t,params):
    
    tau1 = params[0]
    tau2 = params[1]
    amp1 = params[2]
    amp2 = -params[3]
    t0 = params[4]
    
    res = np.zeros(len(t))
    
    for i,ti in enumerate(t): 
 
        if ti < t0:
            res[i] =  0
        else: 
            res[i] = amp1 * ((ti-t0)/tau1) * np.exp(1 - (ti-t0)/tau1)  + amp2 * ((ti-t0)/tau2) * np.exp(1 - (ti-t0)/tau2) 
    
    return res


time = np.arange(0,1,.02)

# %% [markdown]
# # Approximate Filter from real STA from data

# %%
#read sta info
filename = "/user/sebert/home/Documents/Experiments/Results/20210326_Thomas/resultfiles/sta_data.pkl"
with open(filename, "rb") as handle:   #Pickling
    stadict = pickle.load(handle)
    
stadict.keys()

STAs = stadict['STAs']
rasters_check_rep = stadict['rasters_check_repeated']
rasters_check = stadict['rasters_check']
temporal = stadict['temporal']
spatial = stadict['spatial']


nb_staframes = 40
frame_rate = 1/40
filtertime = np.arange(0,nb_staframes)*frame_rate


c = 242
time_rf = np.flip(temporal[c])
time_rf_smooth = gaussian_filter(time_rf,1)
data = time_rf_smooth.copy()


fig = plt.figure()
ax3 = fig.add_subplot(111)
#ax3.plot(filtertime,time_rf)
ax3.scatter(filtertime,time_rf_smooth)
ax3.set_xlabel('time [s]')
ax3.set_ylabel('Stimulus Intensity')
ax3.set_title('temporal')
# Out:
# Text(0.5, 1.0, 'temporal')

# %%
# %matplotlib inline
#choose some time params and generate a STA with them 

tau1_init = .18
tau2_init = .20
amp1_init = 2
amp2_init = 1.7
t0_init = 0.05

params_init = [tau1_init,tau2_init, amp1_init,amp2_init, t0_init]

pred_init = linear_filter_model(filtertime,params_init)
loss_init = compute_mse(data,pred_init)

plt.figure()
plt.scatter(filtertime,time_rf_smooth)
plt.plot(filtertime,pred_init)
print(f'Cost is {loss_init}')
# Out:
# Cost is 0.13725237385230207

# %%
#x0 = np.log(params_init.copy())
x0 = params_init.copy()
esres = optimize_evol(linear_filter_model,x0)
bestparams = np.exp(esres.result.xbest)
pred_best =linear_filter_model(filtertime,bestparams)
# Out:
# (10_w,20)-aCMA-ES (mu_w=5.9,w_1=27%) in dimension 5 (seed=943612, Mon Feb 14 16:14:58 2022)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     20 9.836871824585731e-02 1.0e+00 3.11e-02  3e-02  3e-02 0:00.0
#     2     40 8.446312765689505e-02 1.4e+00 4.00e-02  3e-02  5e-02 0:00.0
#     3     60 8.045762749733497e-02 1.6e+00 3.97e-02  3e-02  5e-02 0:00.0
#   100   2000 3.602584696558176e-02 6.1e+02 1.68e-01  2e-03  4e-02 0:00.3
#   200   4000 3.597100615403247e-02 3.3e+03 3.88e+00  5e-04  2e-02 0:00.6

# %%
#predict_opt = linear_filter_model(filtertime,params_opt)
# %matplotlib notebook
fig  = plt.figure()
#plt.plot(filtertime,pred_true, color = 'black', label = 'best manually found')
plt.plot(filtertime,pred_best, color = 'blue', label = '$F(t,\mu_{best})$')
plt.plot(filtertime,pred_init, color ='red', label = '$F(t,\mu_{init})$', alpha =.5)
plt.scatter(filtertime,data, color = 'black',alpha = .5,label = 'STA datapoints')
fig.legend()
plt.xlabel("time [s]")
plt.ylabel("Stimulus Intensity")
#print(f'Cost of initial guess is {loss_init}')
#print(f'Cost of gradient opt is {loss[-1]}')
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">
# Text(0, 0.5, 'Stimulus Intensity')

# %%
print('best paramter are: ')
print(f"tau1 = {bestparams[0]:.2f}")
print(f"tau2 = {bestparams[1]:.2f}")
print(f"amp1 = {bestparams[2]:.2f}")
print(f"amp2 = {bestparams[3]:.2f}")
print(f"t0 = {bestparams[4]:.2f}")
# Out:
# best paramter are:
# tau1 = 0.12
# tau2 = 0.12
# amp1 = 12.41
# amp2 = 12.12
# t0 = 0.07

# %% [markdown]
# # Make predictions with LN model
#
# Take the filter fitted to STA and convolve with stimulus, then pass it through a piecewise linear nonlinearity.

# %%
#load stimuli and cell responses 
experiment_name = '20210326'
cell = 242

#load cell response to euler 

def get_euler_response(cell, experiment_name):
    filename = f"/user/sebert/home/Documents/Experiments/Results/{experiment_name}_Thomas/resultfiles/{experiment_name}_euler_grade_isi.pkl"
    with open(filename, "rb") as handle:   #Pickling
        infodict = pickle.load(handle)
    
    return infodict[f'temp_{cell}']['control']['euler_count']


#load  euler stim stimulus 
def get_euler_stimulus():
    stimeuler = pd.read_csv('/user/sebert/home/Documents/Experiments/StimulusDesgin/Euler_Baptiste/euler_luminance_profile.csv')
    euler = np.asarray(stimeuler['luminance'])
    euler = euler/euler.mean()
    euler = euler - euler.std()
    euler_time = np.arange(0,30,0.02)
    
    return euler,euler_time



#load osr info
def get_OSR_response(cell,experiment_name, IDs):
    
    filename = f"/user/sebert/home/Documents/Experiments/Results/{experiment_name}_Thomas/resultfiles/osr_raster_count_peak_slope.pkl"
    with open(filename, "rb") as handle:   #Pickling
        osrdict = pickle.load(handle)
        
    key = f'temp_{cell}'
    
    responses = []
    osr_times = []
    flashstarts = []
    flashends = []
    lastflashends = []
    peaks = []
    
    for ID in IDs:
        
        #get responses
        responses.append(osrdict[key]['control'][ID]["rate_smoothed"])

        #get plotting stuff
        
        flashstarts.append(osrdict['stimulus_info'][ID]['flashstart'])
        flashends.append(osrdict['stimulus_info'][ID]['flashend'])
        osr_times.append(osrdict['stimulus_info'][ID]["osr_time"])
        lastflashends.append(osrdict['stimulus_info'][ID]["lastflashend"])
        peaks.append(osrdict[key]['control'][ID]["peak"])
    return responses,osr_times,flashstarts,flashends,lastflashends,peaks
        

#OSR Stim
def get_OSR_stimulus(experiment_name):
    result_filepath = f'/user/sebert/home/Documents/Experiments/Results/{experiment_name}_Thomas/resultfiles'
    plotstimulus = pd.read_csv(os.path.join(result_filepath, 'plot_stimulus.csv'), index_col = 0)
    IDs = np.array(plotstimulus.columns)
    stimulus_info = pd.read_csv(f'/user/sebert/home/Documents/Experiments/StimulusDesgin/Stimulus_JAN21_OSR_AmacrineInhibition_50Hz/stimulus_OSR_jan21ID_info.csv')
    return plotstimulus, stimulus_info, IDs

# %%
# predictions


def design_matrix_1D(stimulus,td=40):
    
    stimulus_timesteps = stimulus.shape[0]+td
    
    
    stimulus_padded = np.concatenate((np.zeros(td),stimulus))
    X = np.zeros((stimulus_timesteps,td))
    
    for t in range(stimulus_timesteps):
        if t < td:
            continue
        else:
            X[t,:] = stimulus_padded[t-td:t]
    
        
    return X[td+1:,:]
    
 

    
def convolve(stim,sta, dimension = '1D'):
    
    
    if dimension == '2D':
        X = design_matrix_2D(stim)
        sta = sta.ravel()
        
    if dimension == '1D':
        X = design_matrix_1D(stim)
  
    response = np.concatenate((np.zeros(1),np.dot(X,sta)))
    return  response




def N(l,slope = 1 ,threshold = 0):
    
    if l <= threshold:
        return 0
    else:
        return l*slope

    
    
# temporal LN model with two pathways and piecewise nonlinear rectification

def predict(stim,params,slope = 1, threshold = 0):
   
    
    filt = linear_filter_model(filtertime,params)
    
    linear_prediction = convolve(stim,np.flip(filt))

    nonlinear_prediction = np.array([N(l,slope =slope,threshold = threshold) for l in linear_prediction])
    
    
    return linear_prediction, nonlinear_prediction
    

def slope(x,s,i):
    return s * x + i

# %% [markdown]
# # Predict euler response

# %%
#load euler stimulus and cell response
true_response = get_euler_response(c,experiment_name)
euler,euler_time = get_euler_stimulus()

#make prediction, piecewise-linear rectification
model_linear_response_euler, model_nonlinear_response_euler = predict(euler,bestparams,slope = 2, threshold = 0)

# %%
# %matplotlib notebook
fig = plt.figure(figsize = (10,10))
ax1 = fig.add_subplot(211)
ax1.plot(euler_time,euler, color = 'k', label = 'stimulus')
ax2 = fig.add_subplot(212)
ax2.plot(euler_time, true_response, color = 'k', alpha = 0.3, label = 'cell response')
#ax2.plot(euler_time,model_linear_response_euler, color = 'blue',alpha = .3, linewidth = 5, label = 'linear prediction')
ax2.plot(euler_time,model_nonlinear_response_euler, color = 'blue',linewidth = 2, label = 'nonlinear prediction, N')
ax2.set_xlabel('time [s]')
fig.suptitle('Euler Stimulus Response Prediction via LN model')
fig.legend()
# Out:
# <img src="data:image/png;base64,..." width="719.5833333333334">

# %% [markdown]
# # Predict OSR response

# %%
stimuli_df,info,IDs = get_OSR_stimulus(experiment_name)
osr_responses,osr_times,flashstarts,flashends,lastflashends,peaks = get_OSR_response(c,experiment_name,IDs)
delays = np.array(peaks) - np.array(lastflashends)


periods = info['period'].unique()*1000
info
# Out:
#    Unnamed: 0  ID  polarity  period  frequency
# 0           0   1         0    0.16          6
# 1           1   2         0    0.12          8
# 2           2   3         0    0.10         10
# 3           3   4         0    0.08         12
# 4           4   5         0    0.06         16
# 5           5   6       255    0.16          6
# 6           6   7       255    0.12          8
# 7           7   8       255    0.10         10
# 8           8   9       255    0.08         12
# 9           9  10       255    0.06         16

# %%
stimuli= []
predictions_linear = []
predictions_nonlinear = []
delays_predictions = []
for i,ID in enumerate(IDs):
    stimulus = stimuli_df[ID].dropna().values

    stimulus -= stimulus[0]
    stimulus /= np.abs(stimulus).max()

    #make linear prediction
    model_linear_response, model_nonlinear_response = predict(stimulus,bestparams,slope = 5, threshold = 0)
    
    predictions_linear.append(model_linear_response)  
    predictions_nonlinear.append(model_nonlinear_response)
    delays_predictions.append(osr_times[i][np.argmax(model_nonlinear_response)]-lastflashends[i])
    stimuli.append(stimulus)

# %%
# code to plot dark flash respones only
lw = 4

# %matplotlib notebook
fig,ax = plt.subplots(5,1, figsize = (10,5), sharex = True, sharey = 'col')
for i,ID in enumerate(IDs):
    
    if i <= 4 :
        
        for flash in range(12):
            if i == 0 and flash == 0:
                ax[i].axvspan(flashstarts[i][flash]-lastflashends[i],flashends[i][flash]-lastflashends[i], color = 'black', alpha = .3, label = 'dark flash')
            else:
                ax[i].axvspan(flashstarts[i][flash]-lastflashends[i],flashends[i][flash]-lastflashends[i], color = 'black', alpha = .3)

        if i == 0:
            ax[i].plot(osr_times[i]-lastflashends[i],osr_responses[i], color = 'k', alpha = 0.3,linewidth = lw, label = 'cell response')  
            ax[i].plot(osr_times[i]-lastflashends[i],predictions_nonlinear[i], color = 'blue',linewidth = lw, alpha = 1, label = 'LN prediction')
            #ax[i].plot(osr_times[i]-lastflashends[i],predictions_linear[i], color = 'blue',linewidth = 4, alpha = .3, label = 'linear prediction')
            ax[i].axvline(delays[i], color = 'k', alpha = .5, linestyle = ':',linewidth = lw, label = 'cell peak')
            ax[i].axvline(delays_predictions[i], color = 'b', linestyle = ':',linewidth = lw, label = 'LN peak')
        else:
            ax[i].plot(osr_times[i]-lastflashends[i],osr_responses[i],linewidth = lw, color = 'k', alpha = 0.3)  
            ax[i].plot(osr_times[i]-lastflashends[i],predictions_nonlinear[i], linewidth = lw, color = 'blue', alpha = 1)
            #ax[i].plot(osr_times[i]-lastflashends[i],predictions_linear[i], color = 'blue',linewidth = 4, alpha = .3, label = 'linear prediction')
            ax[i].axvline(delays[i], color = 'k', alpha = .5,linewidth = lw, linestyle = ':')
            ax[i].axvline(delays_predictions[i], color = 'b', linewidth = lw, linestyle = ':') 
         
        freq = info['frequency'][i]
        ax[i].set_ylabel(f'{freq} Hz')



        
ax[4].set_xlabel('time [s]')


fig.legend()
fig.suptitle('Cell Response and LN-model prediction to Flash sequences')
# Out:
# <img src="data:image/png;base64,..." width="784.6666666666667">
# Text(0.5, 0.98, 'Cell Response and LN-model prediction to Flash sequences')

# %%
peaks_data = np.array(delays[:5])*1000
peaks_model = np.array(delays_predictions[:5])*1000

popt_data,_ = curve_fit(slope,periods,peaks_data)
popt_model,_ = curve_fit(slope,periods,peaks_model)
plt.figure()
plt.plot(periods,peaks_model, 'b-o', linewidth = lw)
plt.plot(periods,peaks_data, 'k-o', linewidth = lw)
plt.plot(periods,slope(periods,*popt_data), 'k:',linewidth = lw, alpha = .5,label = f'slope = {popt_data[0]:.2f}, data')
plt.plot(periods,slope(periods,*popt_model), 'b:',linewidth = lw, alpha = .5,label = f'slope = {popt_model[0]:.2f}, model')
plt.xlabel('periods [s]')
plt.ylabel('delay [s]')
plt.legend()
plt.title('Predictive Delay Curve')
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">
# Text(0.5, 1.0, 'Predictive Delay Curve')

# %% [markdown]
# # Result
#
# The evolutionary algorithm perfoms better than the custom gradient descent method.
# Howevert, thoe slope is lower.

# %%
# code tp olot bright response as well
# %matplotlib qt
fig,ax = plt.subplots(5,2, figsize = (20,10), sharex = True, sharey = 'col')
for i,ID in enumerate(IDs):
    
    if i <= 4 :
        
        for flash in range(12):
            if i == 0 and flash == 0:
                ax[i,0].axvspan(flashstarts[i][flash]-lastflashends[i],flashends[i][flash]-lastflashends[i], color = 'black', alpha = .3, label = 'dark flash')
            else:
                ax[i,0].axvspan(flashstarts[i][flash]-lastflashends[i],flashends[i][flash]-lastflashends[i], color = 'black', alpha = .3)

        if i == 0:
            ax[i,0].plot(osr_times[i]-lastflashends[i],osr_responses[i], color = 'k', alpha = 0.3, label = 'cell response')  
            ax[i,0].plot(osr_times[i]-lastflashends[i],predictions_nonlinear[i], color = 'blue',linewidth = 2, alpha = 1, label = 'LN prediction')
            #ax[i,0].plot(osr_times[i]-lastflashends[i],predictions_linear[i], color = 'blue',linewidth = 4, alpha = .3, label = 'linear prediction')
            ax[i,0].axvline(delays[i], color = 'k', alpha = .5, linestyle = ':', label = 'cell peak')
            ax[i,0].axvline(delays_predictions[i], color = 'b', linestyle = ':', label = 'LN peak')
        else:
            ax[i,0].plot(osr_times[i]-lastflashends[i],osr_responses[i], color = 'k', alpha = 0.3)  
            ax[i,0].plot(osr_times[i]-lastflashends[i],predictions_nonlinear[i], color = 'blue',linewidth = 2, alpha = 1)
            #ax[i,0].plot(osr_times[i]-lastflashends[i],predictions_linear[i], color = 'blue',linewidth = 4, alpha = .3, label = 'linear prediction')
            ax[i,0].axvline(delays[i], color = 'k', alpha = .5, linestyle = ':')
            ax[i,0].axvline(delays_predictions[i], color = 'b', linestyle = ':') 
         
        freq = info['frequency'][i]
        ax[i,0].set_ylabel(f'{freq} Hz')



    if i > 4 :
        for flash in range(12):
            if i == 5 and flash == 0:
                ax[i-5,1].axvspan(flashstarts[i][flash]-lastflashends[i],flashends[i][flash]-lastflashends[i], color = 'orange', alpha = .3, label = 'bright flash')
            else:
                ax[i-5,1].axvspan(flashstarts[i][flash]-lastflashends[i],flashends[i][flash]-lastflashends[i], color = 'orange', alpha = .3)

        ax[i-5,1].plot(osr_times[i]-lastflashends[i],osr_responses[i], color = 'k', alpha = 0.3)  
        ax[i-5,1].plot(osr_times[i]-lastflashends[i],predictions_nonlinear[i], color = 'blue',linewidth = 2)

        
ax[4,0].set_xlabel('time [s]')
ax[4,1].set_xlabel('time [s]')

fig.suptitle('Cell Response and LN-model prediction to Flash sequences') 
fig.legend()
